# %%
import time

# Define our simulation paths
landing_path = "/Volumes/workspace/default/tmp_landing/sales_data/"
checkpoint_path = "/Volumes/workspace/default/tmp_landing/_checkpoints/sales_ingest"

# 1. Create the simulated CSV data
sample_data = """ticket_id,store_id,sku,quantity,unit_price,timestamp
T5003,GUA01,SKU105,5,1.99,2026-03-13T10:10:00Z
T5004,GUA02,SKU300,1,45.00,2026-03-13T10:15:00Z
T5005,MX01,SKU100,10,5.50,2026-03-13T10:20:00Z
T5006,MX02,SKU505,2,125.00,2026-03-13T10:25:00Z
T5007,GUA01,SKU202,1,8.75,2026-03-13T10:30:00Z
T5008,GUA02,SKU105,12,1.99,2026-03-13T10:35:00Z
T5009,MX01,SKU880,1,250.00,2026-03-13T10:40:00Z
T5010,GUA01,SKU300,3,45.00,2026-03-13T10:45:00Z
T5011,MX02,SKU100,5,5.50,2026-03-13T10:50:00Z
T5012,GUA02,SKU202,2,8.75,2026-03-13T10:55:00Z
T5003,GUA01,SKU105,5,1.99,2026-03-13T10:10:00Z
T5004,GUA02,SKU300,1,45.00,2026-03-13T10:15:00Z
T5005,MX01,SKU100,10,5.50,2026-03-13T10:20:00Z
T5006,MX02,SKU505,2,125.00,2026-03-13T10:25:00Z
T5007,GUA01,SKU202,1,8.75,2026-03-13T10:30:00Z
T5008,GUA02,SKU105,12,1.99,2026-03-13T10:35:00Z
T5009,MX01,SKU880,1,250.00,2026-03-13T10:40:00Z
T5010,GUA01,SKU300,3,45.00,2026-03-13T10:45:00Z
T5011,MX02,SKU100,5,5.50,2026-03-13T10:50:00Z
T5012,GUA02,SKU202,2,8.75,2026-03-13T10:55:00Z
"""

# 2. Simulate the 'System' dropping a file
file_name = f"sales_{int(time.time())}.csv"
dbutils.fs.put(landing_path + file_name, sample_data, overwrite=True)

print(f"System: File {file_name} dropped in {landing_path}")
